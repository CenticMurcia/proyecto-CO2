# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# !ls
# Out:
#  21-12-21-datos.csv	  'Modelos ML'
# 'EDA datos buenos.ipynb'  'Recopilación datos'

# %%
df = pd.read_csv("21-12-21-datos.csv",
                 sep=";",
                 decimal=",",
                 parse_dates=['time_index'],
                 dayfirst=True,
                 index_col="time_index")

# %% [markdown]
# - `pm25`: particulas menores de 2.5 micras
# - `pm10`: particulas menores de 10 micras

# %%
df
# Out:
#                      temperature  relativehumidity   pm25   pm10  \
# time_index
# 2021-09-27 10:00:00        27.34             49.74  11.88  13.00
# 2021-09-27 10:25:00        27.66             49.45   6.75   7.75
# 2021-09-27 10:30:00        27.94             49.70   5.38   6.38
# 2021-09-27 10:35:00        28.03             48.59   4.71   5.71
# 2021-09-27 10:40:00        28.09             48.43   3.62   4.62
# ...                          ...               ...    ...    ...
# 2021-12-31 23:35:00        18.81             50.12  19.40  20.40
# 2021-12-31 23:40:00        18.82             50.13  19.80  20.80
# 2021-12-31 23:45:00        18.78             50.07  20.80  21.80
# 2021-12-31 23:50:00        18.79             50.10  20.40  21.40
# 2021-12-31 23:55:00        18.78             50.01  20.40  21.40
#
#                      numberofincoming  numberofoutgoing     co2  ocupacion
# time_index
# 2021-09-27 10:00:00              68.0              88.0  594.85        0.0
# 2021-09-27 10:25:00             186.0             265.0  590.77        0.0
# 2021-09-27 10:30:00             354.0             492.0  578.66        0.0
# 2021-09-27 10:35:00              80.0             114.0  581.25        0.0
# 2021-09-27 10:40:00             467.0             642.0  586.75        0.0
# ...                               ...               ...     ...        ...
# 2021-12-31 23:35:00               0.0               0.0  409.35        0.0
# 2021-12-31 23:40:00               0.0               0.0  408.84        0.0
# 2021-12-31 23:45:00               0.0               0.0  408.72        0.0
# 2021-12-31 23:50:00               0.0               0.0  408.75        0.0
# 2021-12-31 23:55:00               0.0               0.0  409.57        0.0
#
# [16855 rows x 8 columns]

# %% [markdown]
# # No todos los días tienen la misma cantidad de datos
# **El maximo son:**  24 horas * 60 minutos_por_hora / 5 minutos_de_ventana = **288 filas**

# %%
df.index.normalize().value_counts(sort=False).plot.bar(figsize=(15,5));

# %% [markdown]
# # Estos son los momentos (en azul) en los que no hay datos

# %%
df["gap_beg"] = df.index.to_series().diff(1).shift(-1) > pd.Timedelta('00:05:00')
df["gap_end"] = df.index.to_series().diff(1)           > pd.Timedelta('00:05:00')
df["gap"]     = df["gap_beg"] | df["gap_end"]

# %%
print("Hay", df["gap_beg"].sum(), "gaps")
# Out:
# Hay 93 gaps

# %%
df["gap"].astype(int).plot.area(figsize=(15,1));

# %%
df["co2"].plot.line(figsize=(15,5))
# Out:
# <AxesSubplot:xlabel='time_index'>

# %%
def min_max_range(boolean_var, min_val, max_val):
    int_var_0_1 = boolean_var.astype(int)
    return int_var_0_1 * (max_val - min_val) + min_val

# %%
min_max_range(df_bueno["gap"], 2,4 )
# Out:
# time_index
# 2021-09-27 10:00:00    4
# 2021-09-27 10:25:00    4
# 2021-09-27 10:30:00    2
# 2021-09-27 10:35:00    2
# 2021-09-27 10:40:00    2
#                       ..
# 2021-12-31 23:35:00    2
# 2021-12-31 23:40:00    2
# 2021-12-31 23:45:00    2
# 2021-12-31 23:50:00    2
# 2021-12-31 23:55:00    2
# Name: gap, Length: 16855, dtype: int64

# %%
def plot_var(filtered_df, var):
    min_val = filtered_df[var].min()
    max_val = filtered_df[var].max()
    
    min_max_range(filtered_df["gap"], min_val, max_val ).plot.area(figsize=(15,5))
    filtered_df[var].plot.line(figsize=(15,5), title=var)
    
    plt.ylim((min_val,max_val))
    plt.show()

# %%
for var in df_bueno.columns[:-3]:
    plot_var(df_bueno.loc['2021-9-30 00:06:00':'2021-10-2 00:23:00'], var)

# %%
for var in df_bueno.columns[:-3]:
    plot_var(df_bueno.loc['2021-10-1':'2021-10-30'], var)

# %%
(df_bueno.ocupacion % 5 != 0).sum()
# Out:
# 1700

# %%
df_bueno.ocupacion.plot.line(figsize=(15,5))
# Out:
# <AxesSubplot:xlabel='time_index'>

# %%
df_bueno.ocupacion.value_counts()[:20]
# Out:
# 0,00     10590
# 15,00     1282
# 5,00       341
# 80,00      327
# 45,00      316
# 60,00      275
# 10,00      271
# 40,00      189
# 35,00      177
# 75,00      174
# 70,00      168
# 50,00      147
# 30,00      141
# 20,00      130
# 65,00      117
# 55,00      110
# 85,00       98
# 25,00       69
# 95,00       55
# 90,00       51
# Name: ocupacion, dtype: int64
