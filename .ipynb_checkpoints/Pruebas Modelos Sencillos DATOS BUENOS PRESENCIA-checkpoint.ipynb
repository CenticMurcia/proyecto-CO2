# %%
# Seed value
# Apparently you may use different seed values at each stage
seed_value= 0

# 1. Set `PYTHONHASHSEED` environment variable at a fixed value
import os
os.environ['PYTHONHASHSEED']=str(seed_value)

# 2. Set `python` built-in pseudo-random generator at a fixed value
import random
random.seed(seed_value)

# 3. Set `numpy` pseudo-random generator at a fixed value
import numpy as np
np.random.seed(seed_value)

# 4. Set the `tensorflow` pseudo-random generator at a fixed value
import tensorflow as tf
# for later versions: 
tf.compat.v1.set_random_seed(seed_value)

# 5. Configure a new global `tensorflow` session
from tensorflow.keras import backend as K
session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
tf.compat.v1.keras.backend.set_session(sess)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import math
from numpy.random import seed
from scipy import stats
from sklearn import preprocessing
import re

from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.model_selection import train_test_split

from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor

# %%
#Defining MAPE function
def mean_absolute_percentage_error(y_true,y_pred):
    mape = np.mean(np.abs((y_true - y_pred)/y_true))*100
    return mape

# %%
# Crea los lags de un df
def lags(dfOriginal, nLag):
    df = dfOriginal.copy()
    for i in df.columns:
        for j in range(1, (nLag+1)):
            palabra = i.split(' ', 1)[0]
            atributo = 'Lag_'+palabra+"_"+str(j)
            df[atributo] = df[i].shift(j)
    
    # Contador para ver cuantos lags hay y así poder eliminar automáticamente los atributos originales
    cont = 0
    for i in df.columns:
        cont = cont + len(re.findall("Lag*", i))
            
    df = df.drop(df.iloc[:, range((len(df.columns)-cont-1))], axis=1) # delete original attributes
    cols = list(df.columns)
    cols = cols[1:] + [cols[0]] 
    df = df[cols]
    
    return df

# %%
# Realiza las prediciones recursivas a h pasos
def recursiveStepsAhead(X_test, y_test, nSteps, scaler, model):
    prueba_X_test = X_test.copy()
    testPredRMSE, testPredMAE, testPredMAPE = [], [], []
    preds = []

    testPredict = model.predict(prueba_X_test)
    lagsco2 = np.sum([len(re.findall("Lag_co2*", i)) for i in X_test.columns])
    
    for p in range(nSteps):
        prueba_X_test = pd.concat([prueba_X_test.iloc[:,:-lagsco2], prueba_X_test.iloc[:,-lagsco2:].shift(1, axis = 1) ], axis=1)
        prueba_X_test['Lag_co2_' + str(1)] = testPredict
        
        testPredict = model.predict(prueba_X_test)

        # invert predictions
        testPredict_transform = scaler.inverse_transform(testPredict.reshape(-1, 1))
        y_test_transform = scaler.inverse_transform(y_test.to_numpy())

        # calculate root mean squared error
        rmse = math.sqrt(mean_squared_error(y_test_transform, testPredict_transform.ravel()))
        mae = mean_absolute_error(y_test_transform, testPredict_transform.ravel())
        mape = mean_absolute_percentage_error(y_test_transform, testPredict_transform.ravel())
        
        testPredRMSE.append(rmse)
        testPredMAE.append(mae)
        testPredMAPE.append(mape)
        
        preds.append(testPredict_transform)
        print('Test Score Step %d' % (p+1))
        print('RMSE %.2f' % (rmse))
        print('MAE %.2f' % (mae))
        print('MAPE %.2f' % (mape))
        
    return testPredRMSE, testPredMAE, testPredMAPE, preds

# %%
def testCO2Quality(df, nSteps, model):
    # normalize the dataset
    scaler = preprocessing.MinMaxScaler(feature_range=(0, 1))
    df_norm = pd.DataFrame(scaler.fit_transform(df), columns=df.columns)

    X_train, X_test, y_train, y_test = train_test_split(df_norm.iloc[:,:-1], df_norm.iloc[:,-1:], 
                                                        test_size=0.3, 
                                                        random_state=seed_value,
                                                       shuffle=False)

    # train the model
    random.seed(seed)
    model = model.fit(X_train, y_train.to_numpy().ravel())

    scaler = preprocessing.MinMaxScaler(feature_range=(0, 1))
    scaler.fit_transform(df['co2'].to_numpy().reshape(-1, 1))

    # recursive steps ahead predictions
    rmse, mae, mape, preds = recursiveStepsAhead(X_test, y_test, nSteps, scaler, model)
    
    y_test_transformed = scaler.inverse_transform(y_test.to_numpy())

    # plot results
    plt.figure(figsize=(10,6))
    plt.plot(y_test_transformed, color='blue', label='Nivel CO2 Real')
    plt.plot(preds[nSteps-1] , color='red', label='Nivel CO2 Predicho')
    plt.xlabel('Date')
    plt.ylabel('Nivel de CO2')
    plt.legend()
    plt.show()
    
    return rmse, mae, mape, preds

# %%
df = pd.read_csv("21-12-21-datos.csv",
                 sep=";",
                 decimal=",",
                 parse_dates=['time_index'],
                 dayfirst=True,
                 index_col="time_index")

# %%
df
# Out:
#                      temperature  relativehumidity   pm25   pm10  \
# time_index
# 2021-09-27 10:00:00        27.34             49.74  11.88  13.00
# 2021-09-27 10:25:00        27.66             49.45   6.75   7.75
# 2021-09-27 10:30:00        27.94             49.70   5.38   6.38
# 2021-09-27 10:35:00        28.03             48.59   4.71   5.71
# 2021-09-27 10:40:00        28.09             48.43   3.62   4.62
# ...                          ...               ...    ...    ...
# 2021-12-31 23:35:00        18.81             50.12  19.40  20.40
# 2021-12-31 23:40:00        18.82             50.13  19.80  20.80
# 2021-12-31 23:45:00        18.78             50.07  20.80  21.80
# 2021-12-31 23:50:00        18.79             50.10  20.40  21.40
# 2021-12-31 23:55:00        18.78             50.01  20.40  21.40
#
#                      numberofincoming  numberofoutgoing     co2  ocupacion
# time_index
# 2021-09-27 10:00:00              68.0              88.0  594.85        0.0
# 2021-09-27 10:25:00             186.0             265.0  590.77        0.0
# 2021-09-27 10:30:00             354.0             492.0  578.66        0.0
# 2021-09-27 10:35:00              80.0             114.0  581.25        0.0
# 2021-09-27 10:40:00             467.0             642.0  586.75        0.0
# ...                               ...               ...     ...        ...
# 2021-12-31 23:35:00               0.0               0.0  409.35        0.0
# 2021-12-31 23:40:00               0.0               0.0  408.84        0.0
# 2021-12-31 23:45:00               0.0               0.0  408.72        0.0
# 2021-12-31 23:50:00               0.0               0.0  408.75        0.0
# 2021-12-31 23:55:00               0.0               0.0  409.57        0.0
#
# [16855 rows x 8 columns]

# %%
ocupacion = pd.read_csv("ctcount-acces-data-RAW-2020-data.csv",
                 sep=",",
                 decimal=",",
                 parse_dates=['time_index'],
                 dayfirst=True,
                 index_col="time_index")

# %%
# Para que todos los segundos sean 00
ocupacion = ocupacion.set_index(ocupacion.index.floor('T'), drop=True)

# %%
ocupacion['ocupacion'] = pd.to_numeric(ocupacion['numberofincoming']) - pd.to_numeric(ocupacion['numberofoutgoing'])
ocupacion
# Out:
#                             endpoint  devicename numberofincoming  \
# time_index
# 2021-09-23 07:06:00  HOPac67b2cd450a  urdecomaq2             2.00
# 2021-09-23 07:07:00  HOPac67b2cd450a  urdecomaq2             2.00
# 2021-09-23 07:08:00  HOPac67b2cd450a  urdecomaq2             2.00
# 2021-09-23 07:09:00  HOPac67b2cd450a  urdecomaq2             2.00
# 2021-09-23 07:10:00  HOPac67b2cd450a  urdecomaq2             2.00
# ...                              ...         ...              ...
# 2022-01-31 23:55:00  HOPac67b2cd450a  urdecomaq2             0.00
# 2022-01-31 23:56:00  HOPac67b2cd450a  urdecomaq2             0.00
# 2022-01-31 23:57:00  HOPac67b2cd450a  urdecomaq2             0.00
# 2022-01-31 23:58:00  HOPac67b2cd450a  urdecomaq2             0.00
# 2022-01-31 23:59:00  HOPac67b2cd450a  urdecomaq2             0.00
#
#                     numberofoutgoing  ocupacion
# time_index
# 2021-09-23 07:06:00             2.00        0.0
# 2021-09-23 07:07:00             2.00        0.0
# 2021-09-23 07:08:00             2.00        0.0
# 2021-09-23 07:09:00             2.00        0.0
# 2021-09-23 07:10:00             2.00        0.0
# ...                              ...        ...
# 2022-01-31 23:55:00             0.00        0.0
# 2022-01-31 23:56:00             0.00        0.0
# 2022-01-31 23:57:00             0.00        0.0
# 2022-01-31 23:58:00             0.00        0.0
# 2022-01-31 23:59:00             0.00        0.0
#
# [171318 rows x 5 columns]

# %%
ocupacion.describe()
# Out:
#            ocupacion
# count  171318.000000
# mean        3.001459
# std         5.581391
# min       -23.000000
# 25%         0.000000
# 50%         0.000000
# 75%         6.000000
# max        22.000000

# %%
ocupacion[ocupacion['ocupacion'] < 0]
# Out:
#                             endpoint  devicename numberofincoming  \
# time_index
# 2021-09-23 07:55:00  HOPac67b2cd450a  urdecomaq2             8.00
# 2021-09-23 07:55:00  HOPac67b2cd450a  urdecomaq2             9.00
# 2021-09-23 07:55:00  HOPac67b2cd450a  urdecomaq2             9.00
# 2021-09-23 07:55:00  HOPac67b2cd450a  urdecomaq2            10.00
# 2021-09-23 07:55:00  HOPac67b2cd450a  urdecomaq2            10.00
# ...                              ...         ...              ...
# 2022-01-31 22:56:00  HOPac67b2cd450a  urdecomaq2            90.00
# 2022-01-31 22:57:00  HOPac67b2cd450a  urdecomaq2            90.00
# 2022-01-31 22:58:00  HOPac67b2cd450a  urdecomaq2            90.00
# 2022-01-31 22:59:00  HOPac67b2cd450a  urdecomaq2            90.00
# 2022-01-31 23:00:00  HOPac67b2cd450a  urdecomaq2            90.00
#
#                     numberofoutgoing  ocupacion
# time_index
# 2021-09-23 07:55:00             9.00       -1.0
# 2021-09-23 07:55:00            10.00       -1.0
# 2021-09-23 07:55:00            11.00       -2.0
# 2021-09-23 07:55:00            11.00       -1.0
# 2021-09-23 07:55:00            12.00       -2.0
# ...                              ...        ...
# 2022-01-31 22:56:00            93.00       -3.0
# 2022-01-31 22:57:00            93.00       -3.0
# 2022-01-31 22:58:00            93.00       -3.0
# 2022-01-31 22:59:00            93.00       -3.0
# 2022-01-31 23:00:00            93.00       -3.0
#
# [14453 rows x 5 columns]

# %%
# Porcentaje de datos negativos de ocupación
14453/171318*100
# Out:
# 8.436358117652553

# %%
# Los datos de presencia negativos se ponen a 0
ocupacion[ocupacion['ocupacion'] < 0] = 0

# %%
df_final = df[['temperature', 'relativehumidity', 'pm25', 'pm10', 'co2']]
# df_final.reset_index(inplace=True, drop=True)
df_final
# Out:
#                      temperature  relativehumidity   pm25   pm10     co2
# time_index
# 2021-09-27 10:00:00        27.34             49.74  11.88  13.00  594.85
# 2021-09-27 10:25:00        27.66             49.45   6.75   7.75  590.77
# 2021-09-27 10:30:00        27.94             49.70   5.38   6.38  578.66
# 2021-09-27 10:35:00        28.03             48.59   4.71   5.71  581.25
# 2021-09-27 10:40:00        28.09             48.43   3.62   4.62  586.75
# ...                          ...               ...    ...    ...     ...
# 2021-12-31 23:35:00        18.81             50.12  19.40  20.40  409.35
# 2021-12-31 23:40:00        18.82             50.13  19.80  20.80  408.84
# 2021-12-31 23:45:00        18.78             50.07  20.80  21.80  408.72
# 2021-12-31 23:50:00        18.79             50.10  20.40  21.40  408.75
# 2021-12-31 23:55:00        18.78             50.01  20.40  21.40  409.57
#
# [16855 rows x 5 columns]

# %%
df_final_ocup = df_final.join(ocupacion['ocupacion'])
df_final_ocup = df_final_ocup[['temperature', 'relativehumidity', 'ocupacion', 'pm25', 'pm10', 'co2']]

# %%
# NUMERO DE NA
df_final_ocup['ocupacion'].isna().sum()
# Out:
# 22

# %%
df_final_ocup.dropna(inplace=True)

# NUMERO DE NA
df_final_ocup['ocupacion'].isna().sum()
# Out:
# 0

# %%
df_lags_5 = lags(df_final_ocup, 5) #predecir a 5 minutos
df_lags_5 = df_lags_5.iloc[5:,:].reset_index(drop=True)
df_lags_5
# Out:
#        Lag_temperature_1  Lag_temperature_2  Lag_temperature_3  \
# 0                  25.96              28.06              28.09
# 1                  25.99              25.96              28.06
# 2                  26.00              25.99              25.96
# 3                  26.00              26.00              25.99
# 4                  25.99              26.00              26.00
# ...                  ...                ...                ...
# 17830              18.82              18.82              18.83
# 17831              18.81              18.82              18.82
# 17832              18.82              18.81              18.82
# 17833              18.78              18.82              18.81
# 17834              18.79              18.78              18.82
#
#        Lag_temperature_4  Lag_temperature_5  Lag_relativehumidity_1  \
# 0                  28.09              27.94                   50.89
# 1                  28.09              28.09                   50.76
# 2                  28.06              28.09                   50.53
# 3                  25.96              28.06                   50.60
# 4                  25.99              25.96                   50.71
# ...                  ...                ...                     ...
# 17830              18.86              18.87                   50.07
# 17831              18.83              18.86                   50.12
# 17832              18.82              18.83                   50.13
# 17833              18.82              18.82                   50.07
# 17834              18.81              18.82                   50.10
#
#        Lag_relativehumidity_2  Lag_relativehumidity_3  Lag_relativehumidity_4  \
# 0                       48.02                   48.43                   48.43
# 1                       50.89                   48.02                   48.43
# 2                       50.76                   50.89                   48.02
# 3                       50.53                   50.76                   50.89
# 4                       50.60                   50.53                   50.76
# ...                       ...                     ...                     ...
# 17830                   50.06                   50.07                   50.08
# 17831                   50.07                   50.06                   50.07
# 17832                   50.12                   50.07                   50.06
# 17833                   50.13                   50.12                   50.07
# 17834                   50.07                   50.13                   50.12
#
#        Lag_relativehumidity_5  ...  Lag_pm10_2  Lag_pm10_3  Lag_pm10_4  \
# 0                       49.70  ...        4.62        4.62        4.62
# 1                       48.43  ...       36.88        4.62        4.62
# 2                       48.43  ...       39.14       36.88        4.62
# 3                       48.02  ...       40.38       39.14       36.88
# 4                       50.89  ...       40.50       40.38       39.14
# ...                       ...  ...         ...         ...         ...
# 17830                   50.06  ...       19.70       19.10       18.50
# 17831                   50.08  ...       20.10       19.70       19.10
# 17832                   50.07  ...       20.40       20.10       19.70
# 17833                   50.06  ...       20.80       20.40       20.10
# 17834                   50.07  ...       21.80       20.80       20.40
#
#        Lag_pm10_5  Lag_co2_1  Lag_co2_2  Lag_co2_3  Lag_co2_4  Lag_co2_5  \
# 0            6.38     616.17     579.95     586.75     586.75     578.66
# 1            4.62     617.56     616.17     579.95     586.75     586.75
# 2            4.62     620.53     617.56     616.17     579.95     586.75
# 3            4.62     623.75     620.53     617.56     616.17     579.95
# 4           36.88     617.60     623.75     620.53     617.56     616.17
# ...           ...        ...        ...        ...        ...        ...
# 17830       18.50     409.86     409.15     408.77     408.92     409.00
# 17831       18.50     409.35     409.86     409.15     408.77     408.92
# 17832       19.10     408.84     409.35     409.86     409.15     408.77
# 17833       19.70     408.72     408.84     409.35     409.86     409.15
# 17834       20.10     408.75     408.72     408.84     409.35     409.86
#
#           co2
# 0      617.56
# 1      620.53
# 2      623.75
# 3      617.60
# 4      610.68
# ...       ...
# 17830  409.35
# 17831  408.84
# 17832  408.72
# 17833  408.75
# 17834  409.57
#
# [17835 rows x 31 columns]

# %%
df_lags_10 = lags(df_final_ocup, 10) #predecir a 10 minutos
df_lags_10 = df_lags_10.iloc[10:,:].reset_index(drop=True)
df_lags_10
# Out:
#        Lag_temperature_1  Lag_temperature_2  Lag_temperature_3  \
# 0                  26.05              25.99              26.00
# 1                  26.05              26.05              25.99
# 2                  26.14              26.05              26.05
# 3                  26.17              26.14              26.05
# 4                  26.22              26.17              26.14
# ...                  ...                ...                ...
# 17825              18.82              18.82              18.83
# 17826              18.81              18.82              18.82
# 17827              18.82              18.81              18.82
# 17828              18.78              18.82              18.81
# 17829              18.79              18.78              18.82
#
#        Lag_temperature_4  Lag_temperature_5  Lag_temperature_6  \
# 0                  26.00              25.99              25.96
# 1                  26.00              26.00              25.99
# 2                  25.99              26.00              26.00
# 3                  26.05              25.99              26.00
# 4                  26.05              26.05              25.99
# ...                  ...                ...                ...
# 17825              18.86              18.87              18.86
# 17826              18.83              18.86              18.87
# 17827              18.82              18.83              18.86
# 17828              18.82              18.82              18.83
# 17829              18.81              18.82              18.82
#
#        Lag_temperature_7  Lag_temperature_8  Lag_temperature_9  \
# 0                  28.06              28.09              28.09
# 1                  25.96              28.06              28.09
# 2                  25.99              25.96              28.06
# 3                  26.00              25.99              25.96
# 4                  26.00              26.00              25.99
# ...                  ...                ...                ...
# 17825              18.87              18.90              18.87
# 17826              18.86              18.87              18.90
# 17827              18.87              18.86              18.87
# 17828              18.86              18.87              18.86
# 17829              18.83              18.86              18.87
#
#        Lag_temperature_10  ...  Lag_co2_2  Lag_co2_3  Lag_co2_4  Lag_co2_5  \
# 0                   27.94  ...     617.60     623.75     620.53     617.56
# 1                   28.09  ...     610.68     617.60     623.75     620.53
# 2                   28.09  ...     610.68     610.68     617.60     623.75
# 3                   28.06  ...     614.24     610.68     610.68     617.60
# 4                   25.96  ...     614.41     614.24     610.68     610.68
# ...                   ...  ...        ...        ...        ...        ...
# 17825               18.91  ...     409.15     408.77     408.92     409.00
# 17826               18.87  ...     409.86     409.15     408.77     408.92
# 17827               18.90  ...     409.35     409.86     409.15     408.77
# 17828               18.87  ...     408.84     409.35     409.86     409.15
# 17829               18.86  ...     408.72     408.84     409.35     409.86
#
#        Lag_co2_6  Lag_co2_7  Lag_co2_8  Lag_co2_9  Lag_co2_10     co2
# 0         616.17     579.95     586.75     586.75      578.66  610.68
# 1         617.56     616.17     579.95     586.75      586.75  614.24
# 2         620.53     617.56     616.17     579.95      586.75  614.41
# 3         623.75     620.53     617.56     616.17      579.95  606.56
# 4         617.60     623.75     620.53     617.56      616.17  602.53
# ...          ...        ...        ...        ...         ...     ...
# 17825     408.89     408.49     409.79     409.20      408.69  409.35
# 17826     409.00     408.89     408.49     409.79      409.20  408.84
# 17827     408.92     409.00     408.89     408.49      409.79  408.72
# 17828     408.77     408.92     409.00     408.89      408.49  408.75
# 17829     409.15     408.77     408.92     409.00      408.89  409.57
#
# [17830 rows x 61 columns]

# %%
df_lags_15 = lags(df_final_ocup, 15) #predecir a 15 minutos
df_lags_15 = df_lags_15.iloc[15:,:].reset_index(drop=True)
df_lags_15
# Out:
#        Lag_temperature_1  Lag_temperature_2  Lag_temperature_3  \
# 0                  26.17              26.22              26.17
# 1                  26.17              26.17              26.22
# 2                  26.18              26.17              26.17
# 3                  26.24              26.18              26.17
# 4                  26.24              26.24              26.18
# ...                  ...                ...                ...
# 17820              18.82              18.82              18.83
# 17821              18.81              18.82              18.82
# 17822              18.82              18.81              18.82
# 17823              18.78              18.82              18.81
# 17824              18.79              18.78              18.82
#
#        Lag_temperature_4  Lag_temperature_5  Lag_temperature_6  \
# 0                  26.14              26.05              26.05
# 1                  26.17              26.14              26.05
# 2                  26.22              26.17              26.14
# 3                  26.17              26.22              26.17
# 4                  26.17              26.17              26.22
# ...                  ...                ...                ...
# 17820              18.86              18.87              18.86
# 17821              18.83              18.86              18.87
# 17822              18.82              18.83              18.86
# 17823              18.82              18.82              18.83
# 17824              18.81              18.82              18.82
#
#        Lag_temperature_7  Lag_temperature_8  Lag_temperature_9  \
# 0                  25.99              26.00              26.00
# 1                  26.05              25.99              26.00
# 2                  26.05              26.05              25.99
# 3                  26.14              26.05              26.05
# 4                  26.17              26.14              26.05
# ...                  ...                ...                ...
# 17820              18.87              18.90              18.87
# 17821              18.86              18.87              18.90
# 17822              18.87              18.86              18.87
# 17823              18.86              18.87              18.86
# 17824              18.83              18.86              18.87
#
#        Lag_temperature_10  ...  Lag_co2_7  Lag_co2_8  Lag_co2_9  Lag_co2_10  \
# 0                   25.99  ...     617.60     623.75     620.53      617.56
# 1                   26.00  ...     610.68     617.60     623.75      620.53
# 2                   26.00  ...     610.68     610.68     617.60      623.75
# 3                   25.99  ...     614.24     610.68     610.68      617.60
# 4                   26.05  ...     614.41     614.24     610.68      610.68
# ...                   ...  ...        ...        ...        ...         ...
# 17820               18.91  ...     408.49     409.79     409.20      408.69
# 17821               18.87  ...     408.89     408.49     409.79      409.20
# 17822               18.90  ...     409.00     408.89     408.49      409.79
# 17823               18.87  ...     408.92     409.00     408.89      408.49
# 17824               18.86  ...     408.77     408.92     409.00      408.89
#
#        Lag_co2_11  Lag_co2_12  Lag_co2_13  Lag_co2_14  Lag_co2_15     co2
# 0          616.17      579.95      586.75      586.75      578.66  601.45
# 1          617.56      616.17      579.95      586.75      586.75  596.29
# 2          620.53      617.56      616.17      579.95      586.75  592.24
# 3          623.75      620.53      617.56      616.17      579.95  592.24
# 4          617.60      623.75      620.53      617.56      616.17  587.46
# ...           ...         ...         ...         ...         ...     ...
# 17820      408.38      408.45      408.87      409.12      409.72  409.35
# 17821      408.69      408.38      408.45      408.87      409.12  408.84
# 17822      409.20      408.69      408.38      408.45      408.87  408.72
# 17823      409.79      409.20      408.69      408.38      408.45  408.75
# 17824      408.49      409.79      409.20      408.69      408.38  409.57
#
# [17825 rows x 91 columns]

# %% [markdown]
# # Linear Regression

# %% [markdown]
# ## 5 minutos

# %%
# normalize the dataset
scaler = preprocessing.MinMaxScaler(feature_range=(0, 1))
df_lags_norm_5 = pd.DataFrame(scaler.fit_transform(df_lags_5), columns=df_lags_5.columns)

# %%
X_train, X_test, y_train, y_test = train_test_split(df_lags_norm_5.iloc[:,:-1], df_lags_norm_5.iloc[:,-1:], 
                                                    test_size=0.3, 
                                                    random_state=seed_value,
                                                   shuffle=False)

# %%
random.seed(seed)
modelLR = LinearRegression().fit(X_train, y_train)

# %%
modelLR.coef_
# Out:
# array([[ 9.35231472e-02, -8.22297523e-03, -6.46949474e-02,
#          1.70759850e-02, -4.32331411e-02,  5.01019825e-02,
#         -2.93510659e-02, -4.16996675e-02,  2.23048283e-02,
#         -4.05758376e-04,  2.59984429e-02,  2.71828968e-03,
#         -6.20076620e-03, -6.89155366e-04, -1.67466180e-02,
#          5.11824266e-01, -9.84371967e-01,  1.00972230e-02,
#          2.40103773e-01, -2.79047912e-02, -4.85678368e-01,
#          9.55019416e-01, -1.98398916e-02, -2.25833375e-01,
#          2.15311672e-02,  1.07628326e+00, -3.01760554e-02,
#          2.20249698e-02, -4.59505340e-03, -7.03347206e-02]])

# %%
modelLR.intercept_
# Out:
# array([0.00123336])

# %%
# normalize the dataset
scaler = preprocessing.MinMaxScaler(feature_range=(0, 1))
scaler.fit_transform(df_lags_5['co2'].to_numpy().reshape(-1, 1))
# Out:
# array([[0.14031504],
#        [0.14228486],
#        [0.14442049],
#        ...,
#        [0.00180401],
#        [0.00182391],
#        [0.00236777]])

# %%
# make predictions
trainPredict = modelLR.predict(X_train)
testPredict = modelLR.predict(X_test)

# invert predictions
trainPredict = scaler.inverse_transform(trainPredict.reshape(-1, 1))
y_train_transformed = scaler.inverse_transform(y_train.to_numpy())
testPredict = scaler.inverse_transform(testPredict.reshape(-1, 1))
y_test_transformed = scaler.inverse_transform(y_test.to_numpy())

# calculate root mean squared error
trainScore = math.sqrt(mean_squared_error(y_train_transformed, trainPredict.ravel()))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = math.sqrt(mean_squared_error(y_test_transformed, testPredict.ravel()))
print('Test Score: %.2f RMSE' % (testScore))
# Out:
# Train Score: 12.41 RMSE
# Test Score: 10.30 RMSE

# %%
# Recursive predictions
scaler = preprocessing.MinMaxScaler(feature_range=(0, 1))
scaler.fit_transform(df_lags_5['co2'].to_numpy().reshape(-1, 1))

rmse_5, mae_5, mape_5, preds_5 = recursiveStepsAhead(X_test, y_test, 5, scaler, modelLR)
# Out:
# Test Score Step 1
# RMSE 11.43
# MAE 5.53
# MAPE 52.18
# Test Score Step 2
# RMSE 14.42
# MAE 8.10
# MAPE 52.04
# Test Score Step 3
# RMSE 18.39
# MAE 11.01
# MAPE 51.90
# Test Score Step 4
# RMSE 22.73
# MAE 14.04
# MAPE 51.76
# Test Score Step 5
# RMSE 27.26
# MAE 17.11
# MAPE 51.62

# %%
plt.figure(figsize=(10,6))
plt.plot(y_test_transformed, color='blue', label='Nivel CO2 Real')
plt.plot(preds_5[4] , color='red', label='Nivel CO2 Predicho')
plt.xlabel('Date')
plt.ylabel('Nivel de CO2')
plt.legend()
plt.show()

# %% [markdown]
# ## 10 minutos

# %%
# normalize the dataset
scaler = preprocessing.MinMaxScaler(feature_range=(0, 1))
df_lags_norm_10 = pd.DataFrame(scaler.fit_transform(df_lags_10), columns=df_lags_10.columns)

# %%
X_train, X_test, y_train, y_test = train_test_split(df_lags_norm_10.iloc[:,:-1], df_lags_norm_10.iloc[:,-1:], 
                                                    test_size=0.3, 
                                                    random_state=seed_value,
                                                   shuffle=False)

# %%
random.seed(seed)
modelLR = LinearRegression().fit(X_train, y_train)

# %%
modelLR.coef_
# Out:
# array([[ 8.76535222e-02, -2.93531009e-03, -7.29371609e-02,
#          4.76153326e-03, -3.28548744e-02,  4.20163804e-02,
#         -1.53662314e-02, -2.11782626e-02, -5.94747016e-03,
#          1.39270264e-02,  5.88458672e-02, -3.27253667e-02,
#         -4.55531520e-02,  2.26754727e-02, -2.27593286e-02,
#         -2.97307973e-03,  1.63583346e-02,  1.95082913e-02,
#         -2.41467849e-02,  1.12800977e-02,  2.62295165e-02,
#          3.03330688e-03, -6.35876925e-03, -1.23188184e-03,
#         -1.42446680e-02, -6.43492662e-03,  1.16524058e-02,
#          2.98160880e-03, -1.67529038e-03, -9.92552413e-03,
#          2.87121790e-01, -9.23692934e-01, -1.70532131e-01,
#          2.55227169e-01, -3.49451036e-01,  2.66549092e-01,
#          2.61807948e-01,  6.51312703e-01, -6.81413491e-01,
#          1.30400344e-01, -2.63369743e-01,  8.90196085e-01,
#          1.63722866e-01, -2.36844365e-01,  3.50300907e-01,
#         -2.79699145e-01, -2.43314983e-01, -6.84198157e-01,
#          6.72934785e-01, -9.84321804e-02,  1.06097465e+00,
#         -2.93153860e-02,  2.22243517e-02, -6.63128286e-03,
#         -6.49609104e-04, -1.23460831e-02, -8.51796675e-03,
#         -2.62743758e-02,  1.18919946e-02, -1.76561251e-02]])

# %%
modelLR.intercept_
# Out:
# array([0.00110402])

# %%
scaler = preprocessing.MinMaxScaler(feature_range=(0, 1))
scaler.fit_transform(df_lags_10['co2'].to_numpy().reshape(-1, 1))

rmse_10, mae_10, mape_10, preds_10 = recursiveStepsAhead(X_test, y_test, 10, scaler, modelLR)
# Out:
# Test Score Step 1
# RMSE 11.79
# MAE 5.68
# MAPE 52.19
# Test Score Step 2
# RMSE 15.34
# MAE 8.46
# MAPE 52.06
# Test Score Step 3
# RMSE 19.87
# MAE 11.58
# MAPE 51.92
# Test Score Step 4
# RMSE 24.84
# MAE 14.87
# MAPE 51.79
# Test Score Step 5
# RMSE 30.01
# MAE 18.22
# MAPE 51.66
# Test Score Step 6
# RMSE 35.29
# MAE 21.60
# MAPE 51.52
# Test Score Step 7
# RMSE 40.61
# MAE 25.01
# MAPE 51.39
# Test Score Step 8
# RMSE 45.97
# MAE 28.41
# MAPE 51.27
# Test Score Step 9
# RMSE 51.33
# MAE 31.82
# MAPE 51.14
# Test Score Step 10
# RMSE 56.69
# MAE 35.22
# MAPE 51.02

# %%
plt.figure(figsize=(10,6))
plt.plot(y_test_transformed, color='blue', label='Nivel CO2 Real')
plt.plot(preds_10[9] , color='red', label='Nivel CO2 Predicho')
plt.xlabel('Date')
plt.ylabel('Nivel de CO2')
plt.legend()
plt.show()

# %% [markdown]
# ## 15 minutos

# %%
# normalize the dataset
scaler = preprocessing.MinMaxScaler(feature_range=(0, 1))
df_lags_norm_15 = pd.DataFrame(scaler.fit_transform(df_lags_15), columns=df_lags_15.columns)

# %%
X_train, X_test, y_train, y_test = train_test_split(df_lags_norm_15.iloc[:,:-1], df_lags_norm_15.iloc[:,-1:], 
                                                    test_size=0.3, 
                                                    random_state=seed_value,
                                                   shuffle=False)

# %%
random.seed(seed)
modelLR = LinearRegression().fit(X_train, y_train)

# %%
modelLR.coef_
# Out:
# array([[ 8.03513825e-02, -4.22479452e-03, -7.30462141e-02,
#          7.97984661e-03, -3.16198279e-02,  3.42755076e-02,
#         -1.13768298e-02, -6.76275268e-03, -1.04024629e-02,
#          5.05054722e-02, -2.45761837e-02, -1.67919644e-02,
#         -6.66604688e-03,  3.13942360e-02, -2.12244046e-02,
#          5.78101759e-02, -3.10965360e-02, -4.32568954e-02,
#          2.16279408e-02, -2.16704912e-02, -3.50951908e-03,
#          1.94731210e-02,  1.60457278e-02, -1.41159171e-02,
#          2.95694512e-02, -7.92262167e-02,  3.63815055e-02,
#         -3.40895065e-03,  2.77320755e-02, -1.19562019e-02,
#          2.55745654e-02,  3.16527267e-03, -5.13477922e-03,
#         -2.15938161e-03, -1.39364515e-02, -7.32984150e-03,
#          1.22177656e-02,  2.67671154e-03, -1.05587098e-03,
#         -2.57282386e-03,  8.39746336e-03, -8.87792599e-03,
#         -7.05891370e-03,  7.57207611e-03, -8.04237318e-03,
#          2.32816454e-01, -1.05310488e+00,  1.33073195e-01,
#          3.91300400e-01, -4.24708167e-01,  3.82862851e-01,
#         -4.32103433e-02,  9.72742187e-01, -9.72067832e-01,
#         -2.29667676e-01,  6.09400267e-01, -2.38698785e-01,
#          2.57288968e-02, -9.26625743e-01,  1.08826811e+00,
#         -2.11473043e-01,  1.02126121e+00, -1.38957731e-01,
#         -3.72343574e-01,  4.27012582e-01, -4.04575749e-01,
#          6.97733930e-02, -1.01215419e+00,  9.70896212e-01,
#          2.47232152e-01, -5.75515058e-01,  2.01322686e-01,
#         -4.85881651e-03,  9.22259413e-01, -1.09139036e+00,
#          1.05985230e+00, -2.98727725e-02,  2.28030996e-02,
#         -7.00710273e-03,  7.07139525e-04, -1.25394462e-02,
#         -1.29990259e-02, -2.92601750e-02,  9.69535204e-03,
#         -2.16815351e-02, -4.68997076e-03,  1.47051459e-02,
#          1.24209173e-02,  3.43780266e-02, -4.22011962e-02]])

# %%
modelLR.intercept_
# Out:
# array([0.00105031])

# %%
scaler = preprocessing.MinMaxScaler(feature_range=(0, 1))
scaler.fit_transform(df_lags_15['co2'].to_numpy().reshape(-1, 1))

rmse_15, mae_15, mape_15, preds_15 = recursiveStepsAhead(X_test, y_test, 15, scaler, modelLR)
# Out:
# Test Score Step 1
# RMSE 11.83
# MAE 5.86
# MAPE 52.22
# Test Score Step 2
# RMSE 15.51
# MAE 8.70
# MAPE 52.10
# Test Score Step 3
# RMSE 20.18
# MAE 11.86
# MAPE 51.98
# Test Score Step 4
# RMSE 25.30
# MAE 15.19
# MAPE 51.86
# Test Score Step 5
# RMSE 30.62
# MAE 18.60
# MAPE 51.74
# Test Score Step 6
# RMSE 36.04
# MAE 22.06
# MAPE 51.62
# Test Score Step 7
# RMSE 41.53
# MAE 25.56
# MAPE 51.51
# Test Score Step 8
# RMSE 47.04
# MAE 29.05
# MAPE 51.40
# Test Score Step 9
# RMSE 52.57
# MAE 32.54
# MAPE 51.30
# Test Score Step 10
# RMSE 58.11
# MAE 36.01
# MAPE 51.20
# Test Score Step 11
# RMSE 63.65
# MAE 39.47
# MAPE 51.11
# Test Score Step 12
# RMSE 69.16
# MAE 42.91
# MAPE 51.03
# Test Score Step 13
# RMSE 74.67
# MAE 46.34
# MAPE 50.95
# Test Score Step 14
# RMSE 80.16
# MAE 49.77
# MAPE 50.88
# Test Score Step 15
# RMSE 85.62
# MAE 53.19
# MAPE 50.81

# %%
plt.figure(figsize=(10,6))
plt.plot(y_test_transformed, color='blue', label='Nivel CO2 Real')
plt.plot(preds_15[14] , color='red', label='Nivel CO2 Predicho')
plt.xlabel('Date')
plt.ylabel('Nivel de CO2')
plt.legend()
plt.show()

# %% [markdown]
# # Random Forest

# %%
rmse_rf_5, mae_rf_5, mape_rf_5, preds_rf_5 = testCO2Quality(df_lags_5, 5, RandomForestRegressor(random_state=seed_value))
# Out:
# Test Score Step 1
# RMSE 32.59
# MAE 14.57
# MAPE 51.79
# Test Score Step 2
# RMSE 36.27
# MAE 18.89
# MAPE 51.78
# Test Score Step 3
# RMSE 41.20
# MAE 23.90
# MAPE 51.84
# Test Score Step 4
# RMSE 47.27
# MAE 29.13
# MAPE 51.95
# Test Score Step 5
# RMSE 53.92
# MAE 34.36
# MAPE 52.14

# %%
rmse_rf_10, mae_rf_10, mape_rf_10, preds_rf_10 = testCO2Quality(df_lags_10, 10, RandomForestRegressor(random_state=seed_value))
# Out:
# Test Score Step 1
# RMSE 35.47
# MAE 15.79
# MAPE 51.57
# Test Score Step 2
# RMSE 39.43
# MAE 20.99
# MAPE 51.46
# Test Score Step 3
# RMSE 44.46
# MAE 26.83
# MAPE 51.45
# Test Score Step 4
# RMSE 50.66
# MAE 32.66
# MAPE 51.53
# Test Score Step 5
# RMSE 58.27
# MAE 39.16
# MAPE 51.71
# Test Score Step 6
# RMSE 67.28
# MAE 46.48
# MAPE 51.99
# Test Score Step 7
# RMSE 78.05
# MAE 54.85
# MAPE 52.43
# Test Score Step 8
# RMSE 90.78
# MAE 64.15
# MAPE 53.02
# Test Score Step 9
# RMSE 104.04
# MAE 73.68
# MAPE 53.70
# Test Score Step 10
# RMSE 118.47
# MAE 83.95
# MAPE 54.50

# %%
rmse_rf_15, mae_rf_15, mape_rf_15, preds_rf_15 = testCO2Quality(df_lags_15, 15, RandomForestRegressor(random_state=seed_value))
# Out:
# Test Score Step 1
# RMSE 36.82
# MAE 16.57
# MAPE 51.39
# Test Score Step 2
# RMSE 40.74
# MAE 21.70
# MAPE 51.26
# Test Score Step 3
# RMSE 46.02
# MAE 27.47
# MAPE 51.23
# Test Score Step 4
# RMSE 52.73
# MAE 34.00
# MAPE 51.26
# Test Score Step 5
# RMSE 61.09
# MAE 41.32
# MAPE 51.45
# Test Score Step 6
# RMSE 70.57
# MAE 49.17
# MAPE 51.76
# Test Score Step 7
# RMSE 81.84
# MAE 58.01
# MAPE 52.23
# Test Score Step 8
# RMSE 95.55
# MAE 68.34
# MAPE 52.88
# Test Score Step 9
# RMSE 110.25
# MAE 79.30
# MAPE 53.67
# Test Score Step 10
# RMSE 125.34
# MAE 90.24
# MAPE 54.52
# Test Score Step 11
# RMSE 139.43
# MAE 100.45
# MAPE 55.37
# Test Score Step 12
# RMSE 152.94
# MAE 110.08
# MAPE 56.20
# Test Score Step 13
# RMSE 166.11
# MAE 119.36
# MAPE 57.03
# Test Score Step 14
# RMSE 177.55
# MAE 127.50
# MAPE 57.78
# Test Score Step 15
# RMSE 186.32
# MAE 133.87
# MAPE 58.38

# %% [markdown]
# # PM2.5

# %%
# Realiza las prediciones recursivas a h pasos
def recursiveStepsAhead(X_test, y_test, nSteps, scaler, model):
    prueba_X_test = X_test.copy()
    testPredRMSE, testPredMAE, testPredMAPE = [], [], []
    preds = []

    testPredict = model.predict(prueba_X_test)
    lagspm25 = np.sum([len(re.findall("Lag_pm25*", i)) for i in X_test.columns])
    
    for p in range(nSteps):
        prueba_X_test = pd.concat([prueba_X_test.iloc[:,:-lagspm25], prueba_X_test.iloc[:,-lagspm25:].shift(1, axis = 1) ], axis=1)
        prueba_X_test['Lag_pm25_' + str(1)] = testPredict
        
        testPredict = model.predict(prueba_X_test)

        # invert predictions
        testPredict_transform = scaler.inverse_transform(testPredict.reshape(-1, 1))
        y_test_transform = scaler.inverse_transform(y_test.to_numpy())

        # calculate root mean squared error
        rmse = math.sqrt(mean_squared_error(y_test_transform, testPredict_transform.ravel()))
        mae = mean_absolute_error(y_test_transform, testPredict_transform.ravel())
        mape = mean_absolute_percentage_error(y_test_transform, testPredict_transform.ravel())
        
        testPredRMSE.append(rmse)
        testPredMAE.append(mae)
        testPredMAPE.append(mape)
        
        preds.append(testPredict_transform)
        print('Test Score Step %d' % (p+1))
        print('RMSE %.2f' % (rmse))
        print('MAE %.2f' % (mae))
        print('MAPE %.2f' % (mape))
        
    return testPredRMSE, testPredMAE, testPredMAPE, preds

# %%
def testPM25Quality(df, nSteps, model):
    # normalize the dataset
    scaler = preprocessing.MinMaxScaler(feature_range=(0, 1))
    df_norm = pd.DataFrame(scaler.fit_transform(df), columns=df.columns)

    X_train, X_test, y_train, y_test = train_test_split(df_norm.iloc[:,:-1], df_norm.iloc[:,-1:], 
                                                        test_size=0.3, 
                                                        random_state=seed_value,
                                                       shuffle=False)

    # train the model
    random.seed(seed)
    model = model.fit(X_train, y_train.to_numpy().ravel())

    scaler = preprocessing.MinMaxScaler(feature_range=(0, 1))
    scaler.fit_transform(df['pm25'].to_numpy().reshape(-1, 1))

    # recursive steps ahead predictions
    rmse, mae, mape, preds = recursiveStepsAhead(X_test, y_test, nSteps, scaler, model)
    
    y_test_transformed = scaler.inverse_transform(y_test.to_numpy())
    
    # plot results
    plt.figure(figsize=(10,6))
    plt.plot(y_test_transformed, color='blue', label='Nivel PM2.5 Real')
    plt.plot(preds[nSteps-1] , color='red', label='Nivel PM2.5 Predicho')
    plt.xlabel('Date')
    plt.ylabel('Nivel de PM2.5')
    plt.legend()
    plt.show()
    
    return rmse, mae, preds

# %%
df_final_pm25 = df_final_ocup[['temperature', 'relativehumidity', 'ocupacion', 'pm10', 'co2', 'pm25']]

# %%
df_lags_5_pm25 = lags(df_final_pm25, 5) #predecir a 5 minutos
df_lags_5_pm25 = df_lags_5_pm25.iloc[5:,:].reset_index(drop=True)
df_lags_5_pm25
# Out:
#        Lag_temperature_1  Lag_temperature_2  Lag_temperature_3  \
# 0                  25.96              28.06              28.09
# 1                  25.99              25.96              28.06
# 2                  26.00              25.99              25.96
# 3                  26.00              26.00              25.99
# 4                  25.99              26.00              26.00
# ...                  ...                ...                ...
# 17830              18.82              18.82              18.83
# 17831              18.81              18.82              18.82
# 17832              18.82              18.81              18.82
# 17833              18.78              18.82              18.81
# 17834              18.79              18.78              18.82
#
#        Lag_temperature_4  Lag_temperature_5  Lag_relativehumidity_1  \
# 0                  28.09              27.94                   50.89
# 1                  28.09              28.09                   50.76
# 2                  28.06              28.09                   50.53
# 3                  25.96              28.06                   50.60
# 4                  25.99              25.96                   50.71
# ...                  ...                ...                     ...
# 17830              18.86              18.87                   50.07
# 17831              18.83              18.86                   50.12
# 17832              18.82              18.83                   50.13
# 17833              18.82              18.82                   50.07
# 17834              18.81              18.82                   50.10
#
#        Lag_relativehumidity_2  Lag_relativehumidity_3  Lag_relativehumidity_4  \
# 0                       48.02                   48.43                   48.43
# 1                       50.89                   48.02                   48.43
# 2                       50.76                   50.89                   48.02
# 3                       50.53                   50.76                   50.89
# 4                       50.60                   50.53                   50.76
# ...                       ...                     ...                     ...
# 17830                   50.06                   50.07                   50.08
# 17831                   50.07                   50.06                   50.07
# 17832                   50.12                   50.07                   50.06
# 17833                   50.13                   50.12                   50.07
# 17834                   50.07                   50.13                   50.12
#
#        Lag_relativehumidity_5  ...  Lag_co2_2  Lag_co2_3  Lag_co2_4  \
# 0                       49.70  ...     579.95     586.75     586.75
# 1                       48.43  ...     616.17     579.95     586.75
# 2                       48.43  ...     617.56     616.17     579.95
# 3                       48.02  ...     620.53     617.56     616.17
# 4                       50.89  ...     623.75     620.53     617.56
# ...                       ...  ...        ...        ...        ...
# 17830                   50.06  ...     409.15     408.77     408.92
# 17831                   50.08  ...     409.86     409.15     408.77
# 17832                   50.07  ...     409.35     409.86     409.15
# 17833                   50.06  ...     408.84     409.35     409.86
# 17834                   50.07  ...     408.72     408.84     409.35
#
#        Lag_co2_5  Lag_pm25_1  Lag_pm25_2  Lag_pm25_3  Lag_pm25_4  Lag_pm25_5  \
# 0         578.66       34.88        3.62        3.62        3.62        5.38
# 1         586.75       37.14       34.88        3.62        3.62        3.62
# 2         586.75       38.38       37.14       34.88        3.62        3.62
# 3         579.95       38.50       38.38       37.14       34.88        3.62
# 4         616.17       38.29       38.50       38.38       37.14       34.88
# ...          ...         ...         ...         ...         ...         ...
# 17830     409.00       19.10       18.70       18.10       17.50       17.50
# 17831     408.92       19.40       19.10       18.70       18.10       17.50
# 17832     408.77       19.80       19.40       19.10       18.70       18.10
# 17833     409.15       20.80       19.80       19.40       19.10       18.70
# 17834     409.86       20.40       20.80       19.80       19.40       19.10
#
#         pm25
# 0      37.14
# 1      38.38
# 2      38.50
# 3      38.29
# 4      37.62
# ...      ...
# 17830  19.40
# 17831  19.80
# 17832  20.80
# 17833  20.40
# 17834  20.40
#
# [17835 rows x 31 columns]

# %%
df_lags_10_pm25 = lags(df_final_pm25, 10) #predecir a 10 minutos
df_lags_10_pm25 = df_lags_10_pm25.iloc[10:,:].reset_index(drop=True)
df_lags_10_pm25
# Out:
#        Lag_temperature_1  Lag_temperature_2  Lag_temperature_3  \
# 0                  26.05              25.99              26.00
# 1                  26.05              26.05              25.99
# 2                  26.14              26.05              26.05
# 3                  26.17              26.14              26.05
# 4                  26.22              26.17              26.14
# ...                  ...                ...                ...
# 17825              18.82              18.82              18.83
# 17826              18.81              18.82              18.82
# 17827              18.82              18.81              18.82
# 17828              18.78              18.82              18.81
# 17829              18.79              18.78              18.82
#
#        Lag_temperature_4  Lag_temperature_5  Lag_temperature_6  \
# 0                  26.00              25.99              25.96
# 1                  26.00              26.00              25.99
# 2                  25.99              26.00              26.00
# 3                  26.05              25.99              26.00
# 4                  26.05              26.05              25.99
# ...                  ...                ...                ...
# 17825              18.86              18.87              18.86
# 17826              18.83              18.86              18.87
# 17827              18.82              18.83              18.86
# 17828              18.82              18.82              18.83
# 17829              18.81              18.82              18.82
#
#        Lag_temperature_7  Lag_temperature_8  Lag_temperature_9  \
# 0                  28.06              28.09              28.09
# 1                  25.96              28.06              28.09
# 2                  25.99              25.96              28.06
# 3                  26.00              25.99              25.96
# 4                  26.00              26.00              25.99
# ...                  ...                ...                ...
# 17825              18.87              18.90              18.87
# 17826              18.86              18.87              18.90
# 17827              18.87              18.86              18.87
# 17828              18.86              18.87              18.86
# 17829              18.83              18.86              18.87
#
#        Lag_temperature_10  ...  Lag_pm25_2  Lag_pm25_3  Lag_pm25_4  \
# 0                   27.94  ...       38.29       38.50       38.38
# 1                   28.09  ...       37.62       38.29       38.50
# 2                   28.09  ...       37.62       37.62       38.29
# 3                   28.06  ...       35.62       37.62       37.62
# 4                   25.96  ...       34.00       35.62       37.62
# ...                   ...  ...         ...         ...         ...
# 17825               18.91  ...       18.70       18.10       17.50
# 17826               18.87  ...       19.10       18.70       18.10
# 17827               18.90  ...       19.40       19.10       18.70
# 17828               18.87  ...       19.80       19.40       19.10
# 17829               18.86  ...       20.80       19.80       19.40
#
#        Lag_pm25_5  Lag_pm25_6  Lag_pm25_7  Lag_pm25_8  Lag_pm25_9  \
# 0           37.14       34.88        3.62        3.62        3.62
# 1           38.38       37.14       34.88        3.62        3.62
# 2           38.50       38.38       37.14       34.88        3.62
# 3           38.29       38.50       38.38       37.14       34.88
# 4           37.62       38.29       38.50       38.38       37.14
# ...           ...         ...         ...         ...         ...
# 17825       17.50       16.80       16.30       15.80       15.80
# 17826       17.50       17.50       16.80       16.30       15.80
# 17827       18.10       17.50       17.50       16.80       16.30
# 17828       18.70       18.10       17.50       17.50       16.80
# 17829       19.10       18.70       18.10       17.50       17.50
#
#        Lag_pm25_10   pm25
# 0             5.38  37.62
# 1             3.62  35.62
# 2             3.62  34.00
# 3             3.62  31.25
# 4            34.88  28.00
# ...            ...    ...
# 17825        15.10  19.40
# 17826        15.80  19.80
# 17827        15.80  20.80
# 17828        16.30  20.40
# 17829        16.80  20.40
#
# [17830 rows x 61 columns]

# %%
df_lags_15_pm25 = lags(df_final_pm25, 15) #predecir a 15 minutos
df_lags_15_pm25 = df_lags_15_pm25.iloc[15:,:].reset_index(drop=True)
df_lags_15_pm25
# Out:
#        Lag_temperature_1  Lag_temperature_2  Lag_temperature_3  \
# 0                  26.17              26.22              26.17
# 1                  26.17              26.17              26.22
# 2                  26.18              26.17              26.17
# 3                  26.24              26.18              26.17
# 4                  26.24              26.24              26.18
# ...                  ...                ...                ...
# 17820              18.82              18.82              18.83
# 17821              18.81              18.82              18.82
# 17822              18.82              18.81              18.82
# 17823              18.78              18.82              18.81
# 17824              18.79              18.78              18.82
#
#        Lag_temperature_4  Lag_temperature_5  Lag_temperature_6  \
# 0                  26.14              26.05              26.05
# 1                  26.17              26.14              26.05
# 2                  26.22              26.17              26.14
# 3                  26.17              26.22              26.17
# 4                  26.17              26.17              26.22
# ...                  ...                ...                ...
# 17820              18.86              18.87              18.86
# 17821              18.83              18.86              18.87
# 17822              18.82              18.83              18.86
# 17823              18.82              18.82              18.83
# 17824              18.81              18.82              18.82
#
#        Lag_temperature_7  Lag_temperature_8  Lag_temperature_9  \
# 0                  25.99              26.00              26.00
# 1                  26.05              25.99              26.00
# 2                  26.05              26.05              25.99
# 3                  26.14              26.05              26.05
# 4                  26.17              26.14              26.05
# ...                  ...                ...                ...
# 17820              18.87              18.90              18.87
# 17821              18.86              18.87              18.90
# 17822              18.87              18.86              18.87
# 17823              18.86              18.87              18.86
# 17824              18.83              18.86              18.87
#
#        Lag_temperature_10  ...  Lag_pm25_7  Lag_pm25_8  Lag_pm25_9  \
# 0                   25.99  ...       38.29       38.50       38.38
# 1                   26.00  ...       37.62       38.29       38.50
# 2                   26.00  ...       37.62       37.62       38.29
# 3                   25.99  ...       35.62       37.62       37.62
# 4                   26.05  ...       34.00       35.62       37.62
# ...                   ...  ...         ...         ...         ...
# 17820               18.91  ...       16.30       15.80       15.80
# 17821               18.87  ...       16.80       16.30       15.80
# 17822               18.90  ...       17.50       16.80       16.30
# 17823               18.87  ...       17.50       17.50       16.80
# 17824               18.86  ...       18.10       17.50       17.50
#
#        Lag_pm25_10  Lag_pm25_11  Lag_pm25_12  Lag_pm25_13  Lag_pm25_14  \
# 0            37.14        34.88         3.62         3.62         3.62
# 1            38.38        37.14        34.88         3.62         3.62
# 2            38.50        38.38        37.14        34.88         3.62
# 3            38.29        38.50        38.38        37.14        34.88
# 4            37.62        38.29        38.50        38.38        37.14
# ...            ...          ...          ...          ...          ...
# 17820        15.10        14.56        14.10        13.80        13.20
# 17821        15.80        15.10        14.56        14.10        13.80
# 17822        15.80        15.80        15.10        14.56        14.10
# 17823        16.30        15.80        15.80        15.10        14.56
# 17824        16.80        16.30        15.80        15.80        15.10
#
#        Lag_pm25_15   pm25
# 0             5.38  26.71
# 1             3.62  24.50
# 2             3.62  22.29
# 3             3.62  22.29
# 4            34.88  20.12
# ...            ...    ...
# 17820        13.40  19.40
# 17821        13.20  19.80
# 17822        13.80  20.80
# 17823        14.10  20.40
# 17824        14.56  20.40
#
# [17825 rows x 91 columns]

# %% [markdown]
# ## Linear Regression

# %%
rmse_lr_5_pm25, mae_lr_5_pm25, preds_lr_5_pm25 = testPM25Quality(df_lags_5_pm25, 5, LinearRegression())
# Out:
# C:\Users\Raquel\anaconda3\envs\centic-env\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until
# Test Score Step 1
# RMSE 2.19
# MAE 1.47
# MAPE inf
# C:\Users\Raquel\anaconda3\envs\centic-env\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until
# Test Score Step 2
# RMSE 4.41
# MAE 2.99
# MAPE inf
# C:\Users\Raquel\anaconda3\envs\centic-env\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until
# Test Score Step 3
# RMSE 24.50
# MAE 16.47
# MAPE inf
# C:\Users\Raquel\anaconda3\envs\centic-env\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until
# Test Score Step 4
# RMSE 91.74
# MAE 61.97
# MAPE inf
# C:\Users\Raquel\anaconda3\envs\centic-env\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until
# Test Score Step 5
# RMSE 392.38
# MAE 264.57
# MAPE inf

# %%
rmse_lr_10_pm25, mae_lr_10_pm25, preds_lr_10_pm25 = testPM25Quality(df_lags_10_pm25, 10, LinearRegression())
# Out:
# C:\Users\Raquel\anaconda3\envs\centic-env\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until
# Test Score Step 1
# RMSE 2.80
# MAE 1.92
# MAPE inf
# C:\Users\Raquel\anaconda3\envs\centic-env\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until
# Test Score Step 2
# RMSE 12.58
# MAE 8.66
# MAPE inf
# C:\Users\Raquel\anaconda3\envs\centic-env\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until
# Test Score Step 3
# RMSE 84.44
# MAE 58.02
# MAPE inf
# C:\Users\Raquel\anaconda3\envs\centic-env\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until
# Test Score Step 4
# RMSE 520.02
# MAE 357.50
# MAPE inf
# C:\Users\Raquel\anaconda3\envs\centic-env\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until
# Test Score Step 5
# RMSE 3260.54
# MAE 2241.35
# MAPE inf
# C:\Users\Raquel\anaconda3\envs\centic-env\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until
# Test Score Step 6
# RMSE 20368.76
# MAE 14002.13
# MAPE inf
# C:\Users\Raquel\anaconda3\envs\centic-env\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until
# Test Score Step 7
# RMSE 127333.26
# MAE 87532.49
# MAPE inf
# C:\Users\Raquel\anaconda3\envs\centic-env\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until
# Test Score Step 8
# RMSE 795907.75
# MAE 547130.05
# MAPE inf
# C:\Users\Raquel\anaconda3\envs\centic-env\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until
# Test Score Step 9
# RMSE 4975011.59
# MAE 3419966.48
# MAPE inf
# C:\Users\Raquel\anaconda3\envs\centic-env\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until
# Test Score Step 10
# RMSE 31097357.13
# MAE 21377221.11
# MAPE inf

# %%
rmse_lr_15_pm25, mae_lr_15_pm25, preds_lr_15_pm25 = testPM25Quality(df_lags_15_pm25, 15, LinearRegression())
# Out:
# C:\Users\Raquel\anaconda3\envs\centic-env\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until
# Test Score Step 1
# RMSE 3.34
# MAE 2.27
# MAPE inf
# C:\Users\Raquel\anaconda3\envs\centic-env\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until
# Test Score Step 2
# RMSE 17.39
# MAE 11.75
# MAPE inf
# C:\Users\Raquel\anaconda3\envs\centic-env\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until
# Test Score Step 3
# RMSE 128.03
# MAE 86.50
# MAPE inf
# C:\Users\Raquel\anaconda3\envs\centic-env\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until
# Test Score Step 4
# RMSE 879.63
# MAE 594.44
# MAPE inf
# C:\Users\Raquel\anaconda3\envs\centic-env\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until
# Test Score Step 5
# RMSE 6130.03
# MAE 4142.41
# MAPE inf
# C:\Users\Raquel\anaconda3\envs\centic-env\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until
# Test Score Step 6
# RMSE 42603.25
# MAE 28789.78
# MAPE inf
# C:\Users\Raquel\anaconda3\envs\centic-env\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until
# Test Score Step 7
# RMSE 296236.25
# MAE 200185.57
# MAPE inf
# C:\Users\Raquel\anaconda3\envs\centic-env\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until
# Test Score Step 8
# RMSE 2059656.54
# MAE 1391840.86
# MAPE inf
# C:\Users\Raquel\anaconda3\envs\centic-env\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until
# Test Score Step 9
# RMSE 14320505.85
# MAE 9677275.43
# MAPE inf
# C:\Users\Raquel\anaconda3\envs\centic-env\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until
# Test Score Step 10
# RMSE 99568204.27
# MAE 67284561.07
# MAPE inf
# C:\Users\Raquel\anaconda3\envs\centic-env\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until
# Test Score Step 11
# RMSE 692282267.16
# MAE 467819106.56
# MAPE inf
# C:\Users\Raquel\anaconda3\envs\centic-env\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until
# Test Score Step 12
# RMSE 4813330715.58
# MAE 3252673342.58
# MAPE inf
# C:\Users\Raquel\anaconda3\envs\centic-env\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until
# Test Score Step 13
# RMSE 33466338838.16
# MAE 22615331178.42
# MAPE inf
# C:\Users\Raquel\anaconda3\envs\centic-env\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until
# Test Score Step 14
# RMSE 232686241302.72
# MAE 157240875174.44
# MAPE inf
# C:\Users\Raquel\anaconda3\envs\centic-env\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until
# Test Score Step 15
# RMSE 1617831193820.81
# MAE 1093271314092.55
# MAPE inf

# %% [markdown]
# ## Random Forest

# %%
rmse_rf_5_pm25, mae_rf_5_pm25, preds_rf_5_pm25 = testPM25Quality(df_lags_5_pm25, 5, RandomForestRegressor(random_state=seed_value))
# Out:
# C:\Users\Raquel\anaconda3\envs\centic-env\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until
# Test Score Step 1
# RMSE 0.72
# MAE 0.40
# MAPE inf
# C:\Users\Raquel\anaconda3\envs\centic-env\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until
# Test Score Step 2
# RMSE 1.16
# MAE 0.45
# MAPE inf
# C:\Users\Raquel\anaconda3\envs\centic-env\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until
# Test Score Step 3
# RMSE 1.44
# MAE 0.48
# MAPE inf
# C:\Users\Raquel\anaconda3\envs\centic-env\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until
# Test Score Step 4
# RMSE 1.48
# MAE 0.49
# MAPE inf
# C:\Users\Raquel\anaconda3\envs\centic-env\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until
# Test Score Step 5
# RMSE 1.48
# MAE 0.49
# MAPE inf

# %%
rmse_rf_10_pm25, mae_rf_10_pm25, preds_rf_10_pm25 = testPM25Quality(df_lags_10_pm25, 10, RandomForestRegressor(random_state=seed_value))
# Out:
# C:\Users\Raquel\anaconda3\envs\centic-env\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until
# Test Score Step 1
# RMSE 0.70
# MAE 0.44
# MAPE inf
# C:\Users\Raquel\anaconda3\envs\centic-env\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until
# Test Score Step 2
# RMSE 0.74
# MAE 0.46
# MAPE inf
# C:\Users\Raquel\anaconda3\envs\centic-env\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until
# Test Score Step 3
# RMSE 0.75
# MAE 0.46
# MAPE inf
# C:\Users\Raquel\anaconda3\envs\centic-env\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until
# Test Score Step 4
# RMSE 0.77
# MAE 0.48
# MAPE inf
# C:\Users\Raquel\anaconda3\envs\centic-env\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until
# Test Score Step 5
# RMSE 0.77
# MAE 0.48
# MAPE inf
# C:\Users\Raquel\anaconda3\envs\centic-env\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until
# Test Score Step 6
# RMSE 0.78
# MAE 0.49
# MAPE inf
# C:\Users\Raquel\anaconda3\envs\centic-env\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until
# Test Score Step 7
# RMSE 0.79
# MAE 0.48
# MAPE inf
# C:\Users\Raquel\anaconda3\envs\centic-env\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until
# Test Score Step 8
# RMSE 0.79
# MAE 0.49
# MAPE inf
# C:\Users\Raquel\anaconda3\envs\centic-env\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until
# Test Score Step 9
# RMSE 0.79
# MAE 0.49
# MAPE inf
# C:\Users\Raquel\anaconda3\envs\centic-env\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until
# Test Score Step 10
# RMSE 0.79
# MAE 0.49
# MAPE inf

# %%
rmse_rf_15_pm25, mae_rf_15_pm25, preds_rf_15_pm25 = testPM25Quality(df_lags_15_pm25, 15, RandomForestRegressor(random_state=seed_value))
# Out:
# C:\Users\Raquel\anaconda3\envs\centic-env\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until
# Test Score Step 1
# RMSE 0.76
# MAE 0.47
# MAPE inf
# C:\Users\Raquel\anaconda3\envs\centic-env\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until
# Test Score Step 2
# RMSE 0.81
# MAE 0.50
# MAPE inf
# C:\Users\Raquel\anaconda3\envs\centic-env\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until
# Test Score Step 3
# RMSE 0.82
# MAE 0.49
# MAPE inf
# C:\Users\Raquel\anaconda3\envs\centic-env\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until
# Test Score Step 4
# RMSE 0.83
# MAE 0.50
# MAPE inf
# C:\Users\Raquel\anaconda3\envs\centic-env\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until
# Test Score Step 5
# RMSE 0.84
# MAE 0.50
# MAPE inf
# C:\Users\Raquel\anaconda3\envs\centic-env\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until
# Test Score Step 6
# RMSE 0.85
# MAE 0.51
# MAPE inf
# C:\Users\Raquel\anaconda3\envs\centic-env\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until
# Test Score Step 7
# RMSE 0.85
# MAE 0.50
# MAPE inf
# C:\Users\Raquel\anaconda3\envs\centic-env\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until
# Test Score Step 8
# RMSE 0.85
# MAE 0.51
# MAPE inf
# C:\Users\Raquel\anaconda3\envs\centic-env\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until
# Test Score Step 9
# RMSE 0.85
# MAE 0.51
# MAPE inf
# C:\Users\Raquel\anaconda3\envs\centic-env\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until
# Test Score Step 10
# RMSE 0.85
# MAE 0.51
# MAPE inf
# C:\Users\Raquel\anaconda3\envs\centic-env\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until
# Test Score Step 11
# RMSE 0.85
# MAE 0.51
# MAPE inf
# C:\Users\Raquel\anaconda3\envs\centic-env\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until
# Test Score Step 12
# RMSE 0.85
# MAE 0.51
# MAPE inf
# C:\Users\Raquel\anaconda3\envs\centic-env\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until
# Test Score Step 13
# RMSE 0.85
# MAE 0.51
# MAPE inf
# C:\Users\Raquel\anaconda3\envs\centic-env\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until
# Test Score Step 14
# RMSE 0.85
# MAE 0.51
# MAPE inf
# C:\Users\Raquel\anaconda3\envs\centic-env\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until
# Test Score Step 15
# RMSE 0.84
# MAE 0.50
# MAPE inf

# %% [markdown]
# # PM10

# %%
# Realiza las prediciones recursivas a h pasos
def recursiveStepsAhead(X_test, y_test, nSteps, scaler, model):
    prueba_X_test = X_test.copy()
    testPredRMSE, testPredMAE, testPredMAPE = [], [], []
    preds = []

    testPredict = model.predict(prueba_X_test)
    lagspm10 = np.sum([len(re.findall("Lag_pm10*", i)) for i in X_test.columns])
    
    for p in range(nSteps):
        prueba_X_test = pd.concat([prueba_X_test.iloc[:,:-lagspm10], prueba_X_test.iloc[:,-lagspm10:].shift(1, axis = 1) ], axis=1)
        prueba_X_test['Lag_pm10_' + str(1)] = testPredict
        
        testPredict = model.predict(prueba_X_test)

        # invert predictions
        testPredict_transform = scaler.inverse_transform(testPredict.reshape(-1, 1))
        y_test_transform = scaler.inverse_transform(y_test.to_numpy())

        # calculate root mean squared error
        rmse = math.sqrt(mean_squared_error(y_test_transform, testPredict_transform.ravel()))
        mae = mean_absolute_error(y_test_transform, testPredict_transform.ravel())
        mape = mean_absolute_percentage_error(y_test_transform, testPredict_transform.ravel())
        
        testPredRMSE.append(rmse)
        testPredMAE.append(mae)
        testPredMAPE.append(mape)
        
        preds.append(testPredict_transform)
        print('Test Score Step %d' % (p+1))
        print('RMSE %.2f' % (rmse))
        print('MAE %.2f' % (mae))
        print('MAE %.2f' % (mape))
        
    return testPredRMSE, testPredMAE, testPredMAPE, preds

# %%
def testPM10Quality(df, nSteps, model):
    # normalize the dataset
    scaler = preprocessing.MinMaxScaler(feature_range=(0, 1))
    df_norm = pd.DataFrame(scaler.fit_transform(df), columns=df.columns)

    X_train, X_test, y_train, y_test = train_test_split(df_norm.iloc[:,:-1], df_norm.iloc[:,-1:], 
                                                        test_size=0.3, 
                                                        random_state=seed_value,
                                                       shuffle=False)

    # train the model
    random.seed(seed)
    model = model.fit(X_train, y_train.to_numpy().ravel())

    scaler = preprocessing.MinMaxScaler(feature_range=(0, 1))
    scaler.fit_transform(df['pm10'].to_numpy().reshape(-1, 1))

    # recursive steps ahead predictions
    rmse, mae, mape, preds = recursiveStepsAhead(X_test, y_test, nSteps, scaler, model)
    
    y_test_transformed = scaler.inverse_transform(y_test.to_numpy())
    
    # plot results
    plt.figure(figsize=(10,6))
    plt.plot(y_test_transformed, color='blue', label='Nivel PM10 Real')
    plt.plot(preds[nSteps-1] , color='red', label='Nivel PM10 Predicho')
    plt.xlabel('Date')
    plt.ylabel('Nivel de PM10')
    plt.legend()
    plt.show()
    
    return rmse, mae, mape, preds

# %%
df_final_pm10 = df_final_ocup[['temperature', 'relativehumidity', 'ocupacion', 'pm25', 'co2', 'pm10']]

# %%
df_lags_5_pm10 = lags(df_final_pm10, 5) #predecir a 5 minutos
df_lags_5_pm10 = df_lags_5_pm10.iloc[5:,:].reset_index(drop=True)
df_lags_5_pm10
# Out:
#        Lag_temperature_1  Lag_temperature_2  Lag_temperature_3  \
# 0                  25.96              28.06              28.09
# 1                  25.99              25.96              28.06
# 2                  26.00              25.99              25.96
# 3                  26.00              26.00              25.99
# 4                  25.99              26.00              26.00
# ...                  ...                ...                ...
# 17830              18.82              18.82              18.83
# 17831              18.81              18.82              18.82
# 17832              18.82              18.81              18.82
# 17833              18.78              18.82              18.81
# 17834              18.79              18.78              18.82
#
#        Lag_temperature_4  Lag_temperature_5  Lag_relativehumidity_1  \
# 0                  28.09              27.94                   50.89
# 1                  28.09              28.09                   50.76
# 2                  28.06              28.09                   50.53
# 3                  25.96              28.06                   50.60
# 4                  25.99              25.96                   50.71
# ...                  ...                ...                     ...
# 17830              18.86              18.87                   50.07
# 17831              18.83              18.86                   50.12
# 17832              18.82              18.83                   50.13
# 17833              18.82              18.82                   50.07
# 17834              18.81              18.82                   50.10
#
#        Lag_relativehumidity_2  Lag_relativehumidity_3  Lag_relativehumidity_4  \
# 0                       48.02                   48.43                   48.43
# 1                       50.89                   48.02                   48.43
# 2                       50.76                   50.89                   48.02
# 3                       50.53                   50.76                   50.89
# 4                       50.60                   50.53                   50.76
# ...                       ...                     ...                     ...
# 17830                   50.06                   50.07                   50.08
# 17831                   50.07                   50.06                   50.07
# 17832                   50.12                   50.07                   50.06
# 17833                   50.13                   50.12                   50.07
# 17834                   50.07                   50.13                   50.12
#
#        Lag_relativehumidity_5  ...  Lag_co2_2  Lag_co2_3  Lag_co2_4  \
# 0                       49.70  ...     579.95     586.75     586.75
# 1                       48.43  ...     616.17     579.95     586.75
# 2                       48.43  ...     617.56     616.17     579.95
# 3                       48.02  ...     620.53     617.56     616.17
# 4                       50.89  ...     623.75     620.53     617.56
# ...                       ...  ...        ...        ...        ...
# 17830                   50.06  ...     409.15     408.77     408.92
# 17831                   50.08  ...     409.86     409.15     408.77
# 17832                   50.07  ...     409.35     409.86     409.15
# 17833                   50.06  ...     408.84     409.35     409.86
# 17834                   50.07  ...     408.72     408.84     409.35
#
#        Lag_co2_5  Lag_pm10_1  Lag_pm10_2  Lag_pm10_3  Lag_pm10_4  Lag_pm10_5  \
# 0         578.66       36.88        4.62        4.62        4.62        6.38
# 1         586.75       39.14       36.88        4.62        4.62        4.62
# 2         586.75       40.38       39.14       36.88        4.62        4.62
# 3         579.95       40.50       40.38       39.14       36.88        4.62
# 4         616.17       40.29       40.50       40.38       39.14       36.88
# ...          ...         ...         ...         ...         ...         ...
# 17830     409.00       20.10       19.70       19.10       18.50       18.50
# 17831     408.92       20.40       20.10       19.70       19.10       18.50
# 17832     408.77       20.80       20.40       20.10       19.70       19.10
# 17833     409.15       21.80       20.80       20.40       20.10       19.70
# 17834     409.86       21.40       21.80       20.80       20.40       20.10
#
#         pm10
# 0      39.14
# 1      40.38
# 2      40.50
# 3      40.29
# 4      39.62
# ...      ...
# 17830  20.40
# 17831  20.80
# 17832  21.80
# 17833  21.40
# 17834  21.40
#
# [17835 rows x 31 columns]

# %%
df_lags_10_pm10 = lags(df_final_pm10, 10) #predecir a 10 minutos
df_lags_10_pm10 = df_lags_10_pm10.iloc[10:,:].reset_index(drop=True)
df_lags_10_pm10
# Out:
#        Lag_temperature_1  Lag_temperature_2  Lag_temperature_3  \
# 0                  26.05              25.99              26.00
# 1                  26.05              26.05              25.99
# 2                  26.14              26.05              26.05
# 3                  26.17              26.14              26.05
# 4                  26.22              26.17              26.14
# ...                  ...                ...                ...
# 17825              18.82              18.82              18.83
# 17826              18.81              18.82              18.82
# 17827              18.82              18.81              18.82
# 17828              18.78              18.82              18.81
# 17829              18.79              18.78              18.82
#
#        Lag_temperature_4  Lag_temperature_5  Lag_temperature_6  \
# 0                  26.00              25.99              25.96
# 1                  26.00              26.00              25.99
# 2                  25.99              26.00              26.00
# 3                  26.05              25.99              26.00
# 4                  26.05              26.05              25.99
# ...                  ...                ...                ...
# 17825              18.86              18.87              18.86
# 17826              18.83              18.86              18.87
# 17827              18.82              18.83              18.86
# 17828              18.82              18.82              18.83
# 17829              18.81              18.82              18.82
#
#        Lag_temperature_7  Lag_temperature_8  Lag_temperature_9  \
# 0                  28.06              28.09              28.09
# 1                  25.96              28.06              28.09
# 2                  25.99              25.96              28.06
# 3                  26.00              25.99              25.96
# 4                  26.00              26.00              25.99
# ...                  ...                ...                ...
# 17825              18.87              18.90              18.87
# 17826              18.86              18.87              18.90
# 17827              18.87              18.86              18.87
# 17828              18.86              18.87              18.86
# 17829              18.83              18.86              18.87
#
#        Lag_temperature_10  ...  Lag_pm10_2  Lag_pm10_3  Lag_pm10_4  \
# 0                   27.94  ...       40.29       40.50       40.38
# 1                   28.09  ...       39.62       40.29       40.50
# 2                   28.09  ...       39.62       39.62       40.29
# 3                   28.06  ...       37.62       39.62       39.62
# 4                   25.96  ...       36.00       37.62       39.62
# ...                   ...  ...         ...         ...         ...
# 17825               18.91  ...       19.70       19.10       18.50
# 17826               18.87  ...       20.10       19.70       19.10
# 17827               18.90  ...       20.40       20.10       19.70
# 17828               18.87  ...       20.80       20.40       20.10
# 17829               18.86  ...       21.80       20.80       20.40
#
#        Lag_pm10_5  Lag_pm10_6  Lag_pm10_7  Lag_pm10_8  Lag_pm10_9  \
# 0           39.14       36.88        4.62        4.62        4.62
# 1           40.38       39.14       36.88        4.62        4.62
# 2           40.50       40.38       39.14       36.88        4.62
# 3           40.29       40.50       40.38       39.14       36.88
# 4           39.62       40.29       40.50       40.38       39.14
# ...           ...         ...         ...         ...         ...
# 17825       18.50       17.80       17.30       16.80       16.80
# 17826       18.50       18.50       17.80       17.30       16.80
# 17827       19.10       18.50       18.50       17.80       17.30
# 17828       19.70       19.10       18.50       18.50       17.80
# 17829       20.10       19.70       19.10       18.50       18.50
#
#        Lag_pm10_10   pm10
# 0             6.38  39.62
# 1             4.62  37.62
# 2             4.62  36.00
# 3             4.62  33.25
# 4            36.88  30.00
# ...            ...    ...
# 17825        16.10  20.40
# 17826        16.80  20.80
# 17827        16.80  21.80
# 17828        17.30  21.40
# 17829        17.80  21.40
#
# [17830 rows x 61 columns]

# %%
df_lags_15_pm10 = lags(df_final_pm10, 15) #predecir a 15 minutos
df_lags_15_pm10 = df_lags_15_pm10.iloc[15:,:].reset_index(drop=True)
df_lags_15_pm10
# Out:
#        Lag_temperature_1  Lag_temperature_2  Lag_temperature_3  \
# 0                  26.17              26.22              26.17
# 1                  26.17              26.17              26.22
# 2                  26.18              26.17              26.17
# 3                  26.24              26.18              26.17
# 4                  26.24              26.24              26.18
# ...                  ...                ...                ...
# 17820              18.82              18.82              18.83
# 17821              18.81              18.82              18.82
# 17822              18.82              18.81              18.82
# 17823              18.78              18.82              18.81
# 17824              18.79              18.78              18.82
#
#        Lag_temperature_4  Lag_temperature_5  Lag_temperature_6  \
# 0                  26.14              26.05              26.05
# 1                  26.17              26.14              26.05
# 2                  26.22              26.17              26.14
# 3                  26.17              26.22              26.17
# 4                  26.17              26.17              26.22
# ...                  ...                ...                ...
# 17820              18.86              18.87              18.86
# 17821              18.83              18.86              18.87
# 17822              18.82              18.83              18.86
# 17823              18.82              18.82              18.83
# 17824              18.81              18.82              18.82
#
#        Lag_temperature_7  Lag_temperature_8  Lag_temperature_9  \
# 0                  25.99              26.00              26.00
# 1                  26.05              25.99              26.00
# 2                  26.05              26.05              25.99
# 3                  26.14              26.05              26.05
# 4                  26.17              26.14              26.05
# ...                  ...                ...                ...
# 17820              18.87              18.90              18.87
# 17821              18.86              18.87              18.90
# 17822              18.87              18.86              18.87
# 17823              18.86              18.87              18.86
# 17824              18.83              18.86              18.87
#
#        Lag_temperature_10  ...  Lag_pm10_7  Lag_pm10_8  Lag_pm10_9  \
# 0                   25.99  ...       40.29       40.50       40.38
# 1                   26.00  ...       39.62       40.29       40.50
# 2                   26.00  ...       39.62       39.62       40.29
# 3                   25.99  ...       37.62       39.62       39.62
# 4                   26.05  ...       36.00       37.62       39.62
# ...                   ...  ...         ...         ...         ...
# 17820               18.91  ...       17.30       16.80       16.80
# 17821               18.87  ...       17.80       17.30       16.80
# 17822               18.90  ...       18.50       17.80       17.30
# 17823               18.87  ...       18.50       18.50       17.80
# 17824               18.86  ...       19.10       18.50       18.50
#
#        Lag_pm10_10  Lag_pm10_11  Lag_pm10_12  Lag_pm10_13  Lag_pm10_14  \
# 0            39.14        36.88         4.62         4.62         4.62
# 1            40.38        39.14        36.88         4.62         4.62
# 2            40.50        40.38        39.14        36.88         4.62
# 3            40.29        40.50        40.38        39.14        36.88
# 4            39.62        40.29        40.50        40.38        39.14
# ...            ...          ...          ...          ...          ...
# 17820        16.10        15.56        15.10        14.80        14.20
# 17821        16.80        16.10        15.56        15.10        14.80
# 17822        16.80        16.80        16.10        15.56        15.10
# 17823        17.30        16.80        16.80        16.10        15.56
# 17824        17.80        17.30        16.80        16.80        16.10
#
#        Lag_pm10_15   pm10
# 0             6.38  28.71
# 1             4.62  25.88
# 2             4.62  23.29
# 3             4.62  23.29
# 4            36.88  21.12
# ...            ...    ...
# 17820        14.40  20.40
# 17821        14.20  20.80
# 17822        14.80  21.80
# 17823        15.10  21.40
# 17824        15.56  21.40
#
# [17825 rows x 91 columns]

# %% [markdown]
# ## Linear Regression

# %%
rmse_lr_5_pm10, mae_lr_5_pm10, mape_lr_5_pm10, preds_lr_5_pm10 = testPM10Quality(df_lags_5_pm10, 5, LinearRegression())
# Out:
# Test Score Step 1
# RMSE 2.12
# MAE 1.43
# MAE 82.12
# Test Score Step 2
# RMSE 12.82
# MAE 8.57
# MAE 197.61
# Test Score Step 3
# RMSE 56.97
# MAE 37.94
# MAE 867.19
# Test Score Step 4
# RMSE 228.10
# MAE 151.59
# MAE 3507.09
# Test Score Step 5
# RMSE 877.85
# MAE 582.89
# MAE 13536.37

# %%
rmse_lr_10_pm10, mae_lr_10_pm10, mape_lr_10_pm10, preds_lr_10_pm10 = testPM10Quality(df_lags_10_pm10, 10, LinearRegression())
# Out:
# Test Score Step 1
# RMSE 2.88
# MAE 1.96
# MAE 85.87
# Test Score Step 2
# RMSE 23.25
# MAE 15.87
# MAE 357.91
# Test Score Step 3
# RMSE 156.85
# MAE 106.98
# MAE 2466.12
# Test Score Step 4
# RMSE 1019.71
# MAE 695.36
# MAE 16134.47
# Test Score Step 5
# RMSE 6579.86
# MAE 4486.70
# MAE 104216.95
# Test Score Step 6
# RMSE 42391.12
# MAE 28905.50
# MAE 671528.52
# Test Score Step 7
# RMSE 273025.07
# MAE 186168.84
# MAE 4325161.14
# Test Score Step 8
# RMSE 1758353.58
# MAE 1198975.91
# MAE 27855278.84
# Test Score Step 9
# RMSE 11324144.86
# MAE 7721641.27
# MAE 179393600.87
# Test Score Step 10
# RMSE 72929591.06
# MAE 49728799.54
# MAE 1155328119.66

# %%
rmse_lr_15_pm10, mae_lr_15_pm10, mape_lr_15_pm10, preds_lr_15_pm10 = testPM10Quality(df_lags_15_pm10, 15, LinearRegression())
# Out:
# Test Score Step 1
# RMSE 3.45
# MAE 2.30
# MAE 90.13
# Test Score Step 2
# RMSE 30.22
# MAE 20.27
# MAE 459.96
# Test Score Step 3
# RMSE 222.50
# MAE 149.12
# MAE 3445.36
# Test Score Step 4
# RMSE 1585.11
# MAE 1062.16
# MAE 24648.60
# Test Score Step 5
# RMSE 11215.65
# MAE 7515.13
# MAE 174509.50
# Test Score Step 6
# RMSE 79247.64
# MAE 53099.98
# MAE 1233152.20
# Test Score Step 7
# RMSE 559802.76
# MAE 375095.78
# MAE 8711042.39
# Test Score Step 8
# RMSE 3954237.87
# MAE 2649535.61
# MAE 61531642.79
# Test Score Step 9
# RMSE 27931010.85
# MAE 18715162.12
# MAE 434632756.96
# Test Score Step 10
# RMSE 197292146.71
# MAE 132195518.54
# MAE 3070051139.60
# Test Score Step 11
# RMSE 1393582913.40
# MAE 933769633.01
# MAE 21685459329.13
# Test Score Step 12
# RMSE 9843641848.98
# MAE 6595727993.28
# MAE 153176314791.65
# Test Score Step 13
# RMSE 69531050490.72
# MAE 46589250515.66
# MAE 1081968466695.82
# Test Score Step 14
# RMSE 491136009231.59
# MAE 329085472023.55
# MAE 7642537702184.32
# Test Score Step 15
# RMSE 3469163457013.42
# MAE 2324511484224.97
# MAE 53983442502485.86

# %% [markdown]
# ## Random Forest

# %%
rmse_rf_5_pm10, mae_rf_5_pm10, mape_rf_5_pm10, preds_rf_5_pm10 = testPM10Quality(df_lags_5_pm10, 5, RandomForestRegressor(random_state=seed_value))
# Out:
# Test Score Step 1
# RMSE 0.71
# MAE 0.40
# MAE 82.73
# Test Score Step 2
# RMSE 0.79
# MAE 0.43
# MAE 82.47
# Test Score Step 3
# RMSE 1.23
# MAE 0.46
# MAE 83.04
# Test Score Step 4
# RMSE 1.41
# MAE 0.48
# MAE 83.20
# Test Score Step 5
# RMSE 1.44
# MAE 0.48
# MAE 83.22

# %%
rmse_rf_10_pm10, mae_rf_10_pm10, mape_rf_10_pm10, preds_rf_10_pm10 = testPM10Quality(df_lags_10_pm10, 10, RandomForestRegressor(random_state=seed_value))
# Out:
# Test Score Step 1
# RMSE 0.75
# MAE 0.46
# MAE 82.89
# Test Score Step 2
# RMSE 0.78
# MAE 0.48
# MAE 82.48
# Test Score Step 3
# RMSE 0.78
# MAE 0.49
# MAE 82.26
# Test Score Step 4
# RMSE 0.79
# MAE 0.49
# MAE 82.20
# Test Score Step 5
# RMSE 0.79
# MAE 0.49
# MAE 82.13
# Test Score Step 6
# RMSE 0.80
# MAE 0.50
# MAE 82.16
# Test Score Step 7
# RMSE 0.80
# MAE 0.50
# MAE 82.11
# Test Score Step 8
# RMSE 0.80
# MAE 0.50
# MAE 82.17
# Test Score Step 9
# RMSE 0.80
# MAE 0.50
# MAE 82.13
# Test Score Step 10
# RMSE 0.80
# MAE 0.50
# MAE 82.20

# %%
rmse_rf_15_pm10, mae_rf_15_pm10, mape_rf_15_pm10, preds_rf_15_pm10 = testPM10Quality(df_lags_15_pm10, 15, RandomForestRegressor(random_state=seed_value))
