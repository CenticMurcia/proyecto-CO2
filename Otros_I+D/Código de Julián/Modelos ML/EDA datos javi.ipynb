# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# !ls
# Out:
#  AplicacionPredictores	 PantallazosSW_HealthyBuilding.docx
# 'EDA datos javi.ipynb'	 Predictores

# %%
dfp  = pd.read_csv("Predictores/calidadAireURDECON.csv", sep=";")
df   = pd.read_csv("AplicacionPredictores/calidadAireURDECON.csv", sep=";")
dfsp = pd.read_csv("AplicacionPredictores/calidadAireURDECON_SIEMPRE_PRESENCIA.csv", sep=";")

# %%
len(dfp), len(df), len(dfsp)
# Out:
# (28208, 16922, 41936)

# %%
dfp.presencia.value_counts().sort_index().plot.bar();

# %%
df.presencia.value_counts().sort_index().plot.bar();

# %%
dfsp.presencia.value_counts().sort_index().plot.bar()
# Out:
# <AxesSubplot:>

# %%
dfsp.presencia.value_counts().sort_index()
# Out:
# -5.0       780
# -4.0       160
# -3.0       549
# -2.0      2333
# -1.0      1832
#  0.0     21312
#  1.0       930
#  2.0       526
#  3.0       481
#  4.0       278
#  5.0       379
#  6.0       560
#  7.0       848
#  8.0       627
#  9.0       590
#  10.0      911
#  11.0      945
#  12.0     1349
#  13.0     1212
#  14.0     1278
#  15.0     1369
#  16.0      980
#  17.0      699
#  18.0      413
#  19.0      421
#  20.0      138
#  21.0       36
# Name: presencia, dtype: int64

# %%
dfsp.presencia.plot.line(figsize=(16,6));

# %%
dfsp
# Out:
#                      fecha  pm25  pm10       co2    humedad  temperatura  \
# 0      09-11-2021 12:58:53   6.0   7.0  760.1181  43.848324    23.990616
# 1      09-11-2021 12:58:53   6.0   7.0  760.1181  43.848324    23.990616
# 2      09-11-2021 12:59:32   5.0   6.0  760.1181  43.848324    23.990616
# 3      09-11-2021 13:00:11   6.0   7.0  760.1181  43.848324    23.990616
# 4      09-11-2021 13:00:51   6.0   7.0  760.1181  43.848324    23.990616
# ...                    ...   ...   ...       ...        ...          ...
# 41931  24-11-2021 10:03:15   1.0   2.0  768.8070  47.437250    21.950485
# 41932  24-11-2021 10:03:45   1.0   2.0  768.8070  47.437250    21.950485
# 41933  24-11-2021 10:04:15   3.0   4.0  795.8940  47.345690    22.035934
# 41934  24-11-2021 10:04:45   2.0   3.0  795.8940  47.345690    22.035934
# 41935  24-11-2021 10:05:15   2.0   3.0  795.8940  47.345690    22.035934
#
#                  t_terabee  presencia
# 0      09-11-2021 12:58:59       20.0 NaN
# ...

# %%
dfsp.pm25.plot.line(figsize=(16,6));

# %%
dfsp[:40000].pm10.plot.line(figsize=(16,3));

# %%
dfsp[:40000].co2.plot.line(figsize=(16,3));

# %%
dfsp[:40000].humedad.plot.line(figsize=(16,3));

# %%
dfsp[:40000].temperatura.plot.line(figsize=(16,3));
